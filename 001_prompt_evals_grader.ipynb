# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 5.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere are several solutions to extract the bucket name from an S3 URI:\n\n## Solution 1: Using String Methods (Simple)\n```python\ndef get_s3_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    # Remove 's3://' prefix and get everything before the first '/'\n    return s3_uri.replace('s3://', '').split('/')[0]\n\n# Test\nuri = \"s3://my-bucket/path/to/file.txt\"\nprint(get_s3_bucket_name(uri))  # Output: my-bucket\n```\n\n## Solution 2: Using Regular Expressions (Robust)\n```python\nimport re\n\ndef get_s3_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using regex\"\"\"\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if match:\n        return match.group(1)\n    return None\n\n# Test\nuri = \"s3://my-bucket/path/to/file.txt\"\nprint(get_s3_bucket_name(uri))  # Output: my-bucket\n```\n\n## Solution 3: Using urllib (Recommended for URIs)\n```python\nfrom urllib.parse import urlparse\n\ndef get_s3_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using urllib\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Test\nuri = \"s3://my-bucket/path/to/file.txt\"\nprint(get_s3_bucket_name(uri))  # Output: my-bucket\n```\n\n## Solution 4: Using boto3 (AWS SDK)\n```python\nfrom botocore.compat import urlsplit\n\ndef get_s3_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using botocore\"\"\"\n    parts = urlsplit(s3_uri)\n    return parts.netloc\n\n# Test\nuri = \"s3://my-bucket/path/to/file.txt\"\nprint(get_s3_bucket_name(uri))  # Output: my-bucket\n```\n\n## Comprehensive Example with Error Handling\n```python\ndef get_s3_bucket_name(s3_uri):\n    \"\"\"\n    Extract bucket name from S3 URI with validation\n    \n    Args:\n        s3_uri: S3 URI string (e.g., s3://bucket-name/path/to/file)\n        \n    Returns:\n        str: Bucket name or None if invalid\n        \n    Raises:\n        ValueError: If URI is invalid\n    \"\"\"\n    if not s3_uri:\n        raise ValueError(\"S3 URI cannot be empty\")\n    \n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    # Remove prefix and split by '/'\n    bucket = s3_uri[5:].split('/')[0]\n    \n    if not bucket:\n        raise ValueError(\"Invalid S3 URI: bucket name is empty\")\n    \n    return bucket\n\n# Test cases\ntest_cases = [\n    \"s3://my-bucket/path/to/file.txt\",\n    \"s3://another-bucket/\",\n    \"s3://bucket-123/deep/nested/path/file.json\",\n]\n\nfor uri in test_cases:\n    try:\n        print(f\"{uri} \u2192 {get_s3_bucket_name(uri)}\")\n    except ValueError as e:\n        print(f\"Error: {e}\")\n```\n\n## Recommendation\n\n- **Simple cases**: Use **Solution 1** (string methods)\n- **Production code**: Use **Solution 3** (urllib) - standard library, reliable\n- **AWS applications**: Use **Solution 4** (botocore) - if you're already using boto3\n- **Validation needed**: Use the comprehensive example above\n\nAll solutions correctly handle the example: `s3://my-bucket/path/to/file.txt` \u2192 `my-bucket`",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., s3://my-bucket/path/to/file.txt) and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates good pedagogical structure and covers multiple approaches with practical examples. However, there's a critical flaw: Solution 3 (recommended for production) doesn't work as intended due to urlparse behavior with non-standard schemes. The comprehensive example is actually the most robust, making the simplified recommendations potentially problematic for production use. The solution would benefit from testing claims against actual behavior and addressing S3 URI variants."
#   },
#   {
#     "output": "# AWS S3 Read-Only Access IAM Policy\n\nHere's a complete JSON policy document that grants read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListSpecificBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name\"\n    },\n    {\n      \"Sid\": \"ReadObjectsInBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:GetObjectTagging\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name/*\"\n    }\n  ]\n}\n```\n\n## Explanation\n\n| Component | Purpose |\n|-----------|---------|\n| **ListBucket** | Allows user to list objects in the bucket |\n| **GetBucketLocation** | Allows user to view bucket region information |\n| **GetObject** | Allows user to read/download objects |\n| **GetObjectVersion** | Allows user to access object versions (if versioning enabled) |\n| **GetObjectTagging** | Allows user to view object tags |\n\n## How to Use\n\n1. **Replace `my-bucket-name`** with your actual S3 bucket name\n2. Go to **IAM Console** \u2192 **Users** \u2192 Select user\n3. Click **Add permissions** \u2192 **Attach policies**\n4. Paste the JSON into the policy editor\n5. Review and create\n\n## Advanced Example (With Restrictions)\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListSpecificBucketWithPrefix\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name\",\n      \"Condition\": {\n        \"StringLike\": {\n          \"s3:prefix\": [\"public/*\"]\n        }\n      }\n    },\n    {\n      \"Sid\": \"ReadObjectsWithPrefix\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name/public/*\"\n    }\n  ]\n}\n```\n\nThis restricts access to only objects under the `public/` prefix.",
#     "test_case": {
#       "task": "Create a JSON policy document that allows read-only access to a specific AWS S3 bucket for an IAM user",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly addresses the core requirement with syntactically valid JSON policies and good ARN resource formatting. The documentation is clear and actionable. However, there are gaps in completeness (missing ListBucketVersions), security depth (no explicit denial rules or conditional restrictions), and some inconsistencies between examples. The policy will function for basic read-only access but could be more robust for production use."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Validator\n\nHere's a Python function that validates AWS EC2 instance ID format:\n\n```python\nimport re\n\ndef is_valid_ec2_instance_id(instance_id: str) -> bool:\n    \"\"\"\n    Validates if a given string is a valid AWS EC2 instance ID format.\n    \n    Valid format: 'i-' followed by 17 hexadecimal characters\n    Example: i-0a1b2c3d4e5f6g7h8\n    \n    Args:\n        instance_id (str): The instance ID string to validate\n        \n    Returns:\n        bool: True if valid, False otherwise\n    \"\"\"\n    # Pattern: 'i-' followed by exactly 17 hexadecimal characters\n    pattern = r'^i-[0-9a-f]{17}$'\n    \n    return bool(re.match(pattern, instance_id))\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Valid instances\n    valid_ids = [\n        \"i-0a1b2c3d4e5f6g7h8\",\n        \"i-1234567890abcdefg\",\n        \"i-ffffffffffffffff\",\n        \"i-0000000000000000\",\n    ]\n    \n    # Invalid instances\n    invalid_ids = [\n        \"i-0a1b2c3d4e5f6g7\",      # Too short (16 chars)\n        \"i-0a1b2c3d4e5f6g7h8j\",   # Too long (19 chars)\n        \"0a1b2c3d4e5f6g7h8\",      # Missing 'i-' prefix\n        \"i_0a1b2c3d4e5f6g7h8\",    # Wrong separator\n        \"i-0a1b2c3d4e5f6g7h8!\",   # Invalid character\n        \"I-0a1b2c3d4e5f6g7h8\",    # Uppercase 'I'\n        \"\",                         # Empty string\n        \"i-\",                       # No digits\n    ]\n    \n    print(\"Valid EC2 Instance IDs:\")\n    for id in valid_ids:\n        result = is_valid_ec2_instance_id(id)\n        print(f\"  {id}: {result}\")\n    \n    print(\"\\nInvalid EC2 Instance IDs:\")\n    for id in invalid_ids:\n        result = is_valid_ec2_instance_id(id)\n        print(f\"  {id}: {result}\")\n```\n\n**Output:**\n```\nValid EC2 Instance IDs:\n  i-0a1b2c3d4e5f6g7h8: True\n  i-1234567890abcdefg: True\n  i-ffffffffffffffff: True\n  i-0000000000000000: True\n\nInvalid EC2 Instance IDs:\n  i-0a1b2c3d4e5f6g7: False\n  i-0a1b2c3d4e5f6g7h8j: False\n  0a1b2c3d4e5f6g7h8: False\n  i_0a1b2c3d4e5f6g7h8: False\n  i-0a1b2c3d4e5f6g7h8!: False\n  I-0a1b2c3d4e5f6g7h8: False\n  \n  i-: False\n```\n\n## Key Points:\n\n1. **Pattern Explanation:**\n   - `^i-` - Starts with literal \"i-\"\n   - `[0-9a-f]{17}` - Exactly 17 hexadecimal characters (0-9, a-f)\n   - `$` - End of string\n\n2. **Features:**\n   - Case-sensitive (requires lowercase 'i')\n   - Validates exact length\n   - Checks for valid hexadecimal characters only\n\n3. **Alternative without regex:**\n```python\ndef is_valid_ec2_instance_id(instance_",
#     "test_case": {
#       "task": "Write a Python function that validates if a given string is a valid AWS EC2 instance ID format (i-followed by 17 hexadecimal characters)",
#       "format": "python"
#     },
#     "score": 4,
#     "reasoning": "The core regex implementation is technically correct and would properly validate EC2 instance IDs. However, the solution is significantly undermined by incorrect test case examples that contradict the stated requirement (g is not a hexadecimal character). This creates confusion about whether the solution actually works as intended. Additionally, the incomplete alternative implementation at the end suggests the response was cut off. For a code review task, these issues are problematic despite the underlying logic being sound."
#   }
# ]
